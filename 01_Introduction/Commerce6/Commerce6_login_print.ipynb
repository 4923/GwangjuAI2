# %% [markdown]
# ## Import Modules

# %%
import numpy as np
import pandas as pd
import re   # 정규표현식 라이브러리

# %% [markdown]
# ## DB Load, DB Upload

# %%
PATH = "./login/Commerce6_login.csv"

def load_df(PATH):
    df = pd.read_csv(PATH, encoding = "euc-kr")
    return df       # 해당 반환값을 변수에 지정하여 활용할 것 

def upload(df):     # parameter : type(df) == dataframe 
    df.to_csv(PATH, encoding="euc-kr", index = False)
    return load_df(PATH)    # return : 업로드한 csv를 df로 변환한 값

# %%
load_df(PATH)
# Out:
#     id    pw      nickname    location
# 0  문재인  1100  moon_justice   서울특별시 종로구
# 1  이준석  1234   bicycle_guy  서울특별시 영등포구
# 2  이명박  3243      liar_lee   서울특별시 서초구

# %% [markdown]
# ## User Information

# %%
class Account:
    def info(self, id):      # return : series
      df = load_df(PATH)
      info = df.loc[df['id'] == id]     # 열을 돌면서 True, False를 반환 (Name : id, dtype : bool)
      return info

# %%
a = Account 
a.info(a, '문재인')

load_df(PATH)
# Out:
#     id    pw      nickname    location
# 0  문재인  1100  moon_justice   서울특별시 종로구
# 1  이준석  1234   bicycle_guy  서울특별시 영등포구
# 2  이명박  3243      liar_lee   서울특별시 서초구

# %% [markdown]
# ## Sign Up

# %%
class Join :
    # def __init__(self, id, pw) :
    #     self.id = id
    #     self.pw = pw

    def join_check(self) :
        # ID 중복 검사 추가, 비밀번호 유효성 추가
        df = load_df(PATH)
        print("데이터 불러오기1")

        join_info = ['id','pw', 'nickname', 'location'] # password -> pw
        # return_info = {}    # [] -> {}
        return_info = []


        # ID 중복 검사 후 가입
        while True :
            input_id = input('{}를 입력해주세요 : '.format(join_info[0]))
            if (len(df.loc[(df['id'] == input_id)])) == 0 :
                # return_info[join_info[0]] = input_id    # modified
                return_info.append(input_id)
                break
            else :
                print("중복된 아이디가 있습니다. 다시 입력해주세요.")

        # 비밀번호 입력
        # while True :
        #     input_pw = input('{}를 입력해주세요 : '.format(join_info[1]))
        #     if len(input_pw) > 8 and re.search('[A-Z]',input_pw) and re.search('[0-9]+',input_pw) and re.search('[~!@#$%^&*(),<.>/?]+',input_pw):
        #         print('사용가능한 비밀번호입니다.')
        #         break
        #     else:
        #         print('비밀번호는 최소 8자 이상, 영문 대문자, 숫자, 특수문자가 포함되어야 합니다.')
        
        # 입력 비밀번호 확인
        while True :
            confirm_pw = input('입력한 {}를 다시 입력해주세요 : '.format(join_info[1]))
            # return_info[join_info[1]] = confirm_pw
            return_info.append(confirm_pw)
            break
            # if confirm_pw == input_pw :
                # return_info[join_info[1]] = confirm_pw    # modified
                # print('입력한 비밀번호와 동일한 것으로 확인되었습니다.')
                # break
            # else:
            #     print('입력한 비밀번호와 다릅니다. 다시 입력해주세요.')        

        # nickName 중복 검사 후 가입
        while True :
            input_nick = input('{}를 입력해주세요 : '.format(join_info[2]))
            if (len(df.loc[(df['nickname'] == input_nick)])) == 0 :
                # return_info[join_info[2]] = input_nick    # modified
                return_info.append(input_nick)

                print("-----------------------------------")
                print(return_info)
                print("-----------------------------------")
                break
            else :
                print("중복된 닉네임이 있습니다. 다시 입력해주세요.")
        
        input_addr = input('{}를 입력해주세요 : '.format(join_info[3]))
        # return_info[join_info[3]] = input_addr    # modified
        return_info.append(input_addr)

        return_info = pd.DataFrame(np.array(return_info).reshape(1, -1), columns=join_info)
        df.append(return_info)
        # print("-----------------------------------")
        # print(return_info)
        # print("-----------------------------------")

        # print("-----------------------------------")
        # print("append 하기 전")
        # print(df)
        # print("-----------------------------------")
        # print("append 후")
        # # df = df.append(return_info)
        # temp = []
        # for i in return_info.values():
        #     temp.append(i)
        #     print(i)
        upload(df)

        

        return "회원가입 완료"

# %%
# dict ={1:'value', 2: "values2"}
# a = dict.values()
# print(a, type(a))
# print()

# li = []
# for element in a:
#     print(element)
#     li.append(element)

# print(li)

# %%
join = Join
join.join_check(join)

load_df(PATH)
# Out:
# 데이터 불러오기1
# -----------------------------------
# ['아이디', '비밀번호', '닉네임']
# -----------------------------------
#     id    pw      nickname    location
# 0  문재인  1100  moon_justice   서울특별시 종로구
# 1  이준석  1234   bicycle_guy  서울특별시 영등포구
# 2  이명박  3243      liar_lee   서울특별시 서초구

# %% [markdown]
# ## Sign In

# %%
class Login :
    # def __init__(self, id, pw) :
    #     self.id = id
    #     self.pw = pw

    def login_check(self, id, pw):
        df = load_df(PATH)
        print(id, type(id))
        print(pw, type(pw))
        print(df.loc[df['pw'] == pw])

        #login_check
        # if len(df.loc[(df['id'] == id) & (df['pw'] == pw)]) == 1 :
        df_to_dict = df.loc[df['id'] == id].iloc[0].to_dict()
        if str(df_to_dict['pw']) == pw:
            print("로그인 성공")
            return True 
        else :
            print("로그인 실패")
            return False

# %%
login = Login 
login.login_check(login, '문재인', '1100')

load_df(PATH)
# Out:
# 문재인 <class 'str'>
# 1100 <class 'str'>
# Empty DataFrame
# Columns: [id, pw, nickname, location]
# Index: []
# 로그인 성공
#     id    pw      nickname    location
# 0  문재인  1100  moon_justice   서울특별시 종로구
# 1  이준석  1234   bicycle_guy  서울특별시 영등포구
# 2  이명박  3243      liar_lee   서울특별시 서초구

# %% [markdown]
# ## Delete Account

# %%
class Delete_account:  # 회원탈퇴, 로그인 한 상황에서만 노출
  def __init__(self, id, pw):
    self.id = id 
    self.pw = pw

  def double_check(self):
    print("확인을 위해 ID 와 PW를 다시 한 번 입력하세요.")
    while True:
      input_id = input("Enter Your [ID] : ")
      if self.id != input_id:
        print(f"{input_id}은/는 잘못된 ID 입니다.")
        status = True
      else: 
        while True:
          input_pw = input("Enter Your [pw] : ")
          if str(self.pw) != input_pw:
            print(f"{input_pw}은/는 잘못된 PW입니다.")

            print("계속하려면 1을, 취소하려면 0을 입력하세요.")
            if int(input("입력 : ")) == 1: return False
          else: 
            return True

  def delete(self):
    print("회원 탈퇴 절차를 진행합니다.")
    df = load_df(PATH)
    cmd = input("정말로 탈퇴하겠습니까? 탈퇴하시려면 y를, 탈퇴하지 않으려면 n을 입력하세요. : ")
    if cmd == 'y': 
      deleted_user = df.loc[df['id'] == self.id].iloc[0].to_dict()
      deleted_user_index = df[ df['id'] == self.id ].index
      df.drop(index = deleted_user_index, inplace=True)
      print(f"{deleted_user['id']}({deleted_user['nickname']})님의 정보가 안전하게 삭제되었습니다.")
      upload(df)
      return True
    elif cmd == 'n':
      print("탈퇴처리를 종료합니다. 고객정보는 유지됩니다.")
      return False

# %% [markdown]
# ## Test Code

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).double_check(): 
                        delete_instance(user_id, user_pw).delete()
                        break

                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")
# Out:
# 문재인 <class 'str'>
# 1100 <class 'str'>
# Empty DataFrame
# Columns: [id, pw, nickname, location]
# Index: []
# 로그인 성공
# 환영합니다. moon_justice님.
# 확인을 위해 ID 와 PW를 다시 한 번 입력하세요.
# 회원 탈퇴 절차를 진행합니다.
# 문재인(moon_justice)님의 정보가 안전하게 삭제되었습니다.

# %%
load_df(PATH)
# Out:
#     id    pw     nickname    location
# 0  이준석  1234  bicycle_guy  서울특별시 영등포구
# 1  이명박  3243     liar_lee   서울특별시 서초구

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).delete(): break # 로그인으로 돌아감
                    else: continue  # 회원 메뉴로 이동
                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")
# Out:
# 문재인 <class 'str'>
# 1100 <class 'str'>
# Empty DataFrame
# Columns: [id, pw, nickname, location]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-f6f93a0b1905> in <module>
#      11         user_id = input("로그인을 위해 ID를 입력하세요 : ")
#      12         user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
# ---> 13         login_status = login_instance.login_check(login_instance, user_id, user_pw)
#      14         if login_status:
#      15             info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
#
# <ipython-input-9-1f156612ba5d> in login_check(self, id, pw)
#      12         #login_check
#      13         # if len(df.loc[(df['id'] == id) & (df['pw'] == pw)]) == 1 :
# ---> 14         df_to_dict = df.loc[df['id'] == id].iloc[0].to_dict()
#      15         if str(df_to_dict['pw']) == pw:
#      16             print("로그인 성공")
#
# ~\.conda\envs\tf2_py38\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\.conda\envs\tf2_py38\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~\.conda\envs\tf2_py38\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
load_df(PATH)

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).delete(): break # 로그인으로 돌아감
                    else: continue  # 회원 메뉴로 이동
                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")

# %%
load_df(PATH)

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).delete(): break # 로그인으로 돌아감
                    else: continue  # 회원 메뉴로 이동
                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).delete(): break # 로그인으로 돌아감
                    else: continue  # 회원 메뉴로 이동
                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")

# %%
account_instance = Account
join_instance = Join
login_instance = Login
delete_instance = Delete_account

# 회원여부 확인 -> 로그인
while True:
    # 회원 전용 기능
    account_check_cmd = int(input("OOO 쇼핑몰에 오신 것을 환영합니다.\n회원이면 1 비회원이면 2 를 입력하세요 : "))
    if account_check_cmd == 1: # 회원이므로 로그인 기능으로 이동
        user_id = input("로그인을 위해 ID를 입력하세요 : ")
        user_pw = input("로그인을 위해 비밀번호를 입력하세요 : ")
        login_status = login_instance.login_check(login_instance, user_id, user_pw)
        if login_status: 
            info_dict = account_instance.info(account_instance, user_id).iloc[0].to_dict()
            print(f"환영합니다. {str(info_dict['nickname'])}님.")
            user_menu_cmd = int(input("원하시는 메뉴의 번호를 입력해주세요.\n\t1. 쇼핑\n\t2. 커뮤니티\n\t3. 회원탈퇴"))
            while user_menu_cmd:
                if user_menu_cmd == 1:
                    print("----------------------------------------------------")
                    print("쇼핑을 시작합니다.")
                    print("----------------------------------------------------")
                    break    # 쇼핑기능으로 이동
                elif user_menu_cmd == 2:
                    print("----------------------------------------------------")
                    print("커뮤니티로 이동합니다.")
                    print("----------------------------------------------------")
                    break    # 커뮤니티 기능으로 이동
                elif user_menu_cmd == 3:
                    if delete_instance(user_id, user_pw).delete(): break # 로그인으로 돌아감
                    else: continue  # 회원 메뉴로 이동
                else:
                    print("잘못된 입력입니다.")
        break
    # 비회원 -> 회원가입 유도
    elif account_check_cmd == 2: # 비회원이므로 회원가입 기능으로 이동
        join_instance.join_check(join_instance)
        break
    else: print("잘못된 입력입니다. 다시 입력하세요")
