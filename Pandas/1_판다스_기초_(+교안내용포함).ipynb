# %%
# https://www.kaggle.com/uciml/pima-indians-diabetes-database

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

print( "--CSV 불러오기 + 판다스 시리즈 선언-------------" )
csv = pd.read_csv('/content/drive/My Drive/lion/PART17/dataset/Historical Product Demand.csv', index_col = 0, squeeze = True) # 구문 분석된 데이터에 열이 하나만 포함되어 있으면 영상 시리즈를 반환합니다.

series = pd.Series( csv )
print( series )
print( "-----------------------------------------" )
# Out:
# --CSV 불러오기 + 판다스 시리즈 선언-------------
# Product_Code
# Product_0993     100
# Product_0979     500
# Product_0979     500
# Product_0979     500
# Product_0979     500
#                 ...
# Product_0021    1500
# Product_0033    1000
# Product_0033    1000
# Product_0021    1000
# Product_0033    1500
# Name: Order_Demand, Length: 12738, dtype: int64
# -----------------------------------------

# %%
print( "--시리즈 데이터 삽입 -------------------------" )
data_list = [3000, 40000, 5000, 7000, 10000, 10000]
data_tuple = (3000, 40000, 5000, 7000, 10000, 10000)
series = pd.Series(data_tuple, index = ["라면", "김치", "떡볶이", "마라탕", "볶음밥", "짬뽕"])
print( series )
print( "-----------------------------------------" )
# data_dic = {"라면" : 3000, "김치" : 40000}
# series = pd.Series( data_dic )
# print( series )
print( "-----------------------------------------" )

print( "--시리즈 데이터 처리 -------------------------" )
print( series[[3]] )
print( series[[0, 1, 2]] )

print( series[0:3] )
print( series["라면":"떡볶이"] )

print( series.index )
print( series.values )
print( "-----------------------------------------" )
# Out:
# --시리즈 데이터 삽입 -------------------------
# 라면      3000
# 김치     40000
# 떡볶이     5000
# 마라탕     7000
# 볶음밥    10000
# 짬뽕     10000
# dtype: int64
# -----------------------------------------
# -----------------------------------------
# --시리즈 데이터 처리 -------------------------
# 마라탕    7000
# dtype: int64
# 라면      3000
# 김치     40000
# 떡볶이     5000
# dtype: int64
# 라면      3000
# 김치     40000
# 떡볶이     5000
# dtype: int64
# 라면      3000
# 김치     40000
# 떡볶이     5000
# dtype: int64
# Index(['라면', '김치', '떡볶이', '마라탕', '볶음밥', '짬뽕'], dtype='object')
# [ 3000 40000  5000  7000 10000 10000]
# -----------------------------------------

# %%
print( "--데이터프레임 데이터 삽입 --------------------" )
# 행, 열, 2차원 이상의 데이터
tuple_data = ((6, 148, 72), (1, 85, 66))
print( pd.DataFrame(tuple_data, columns=["임신", "포도당", "혈압"]) )

df = pd.read_csv('/content/drive/My Drive/lion/PART17/dataset/diabetes.csv', encoding='EUCKR')
print( type(df) )

print( "-----------------------------------------" )
df
# Out:
# --데이터프레임 데이터 삽입 --------------------
#    임신  포도당  혈압
# 0   6  148  72
# 1   1   85  66
# <class 'pandas.core.frame.DataFrame'>
# -----------------------------------------
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 0     6  148  72     35    0  33.6   0.627  50   1
# 1     1   85  66     29    0  26.6   0.351  31   0
# 2     8  183  64      0    0  23.3   0.672  32   1
# 3     1   89  66     23   94  28.1   0.167  21   0
# 4     0  137  40     35  168  43.1   2.288  33   1
# ..   ..  ...  ..    ...  ...   ...     ...  ..  ..
# 763  10  101  76     48  180  32.9   0.171  63   0
# 764   2  122  70     27    0  36.8   0.340  27   0
# 765   5  121  72     23  112  26.2   0.245  30   0
# 766   1  126  60      0    0  30.1   0.349  47   1
# 767   1   93  70     31    0  30.4   0.315  23   0
#
# [768 rows x 9 columns]

# %%
print( df["혈압"] )
print( df.인슐린 )
print( df[["혈압", "인슐린"]])
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: 혈압, Length: 768, dtype: int64
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: 인슐린, Length: 768, dtype: int64
#      혈압  인슐린
# 0    72    0
# 1    66    0
# 2    64    0
# 3    66   94
# 4    40  168
# ..   ..  ...
# 763  76  180
# 764  70    0
# 765  72  112
# 766  60    0
# 767  70    0
#
# [768 rows x 2 columns]

# %%
df.loc[0:5]
# Out:
#    임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 0   6  148  72     35    0  33.6   0.627  50   1
# 1   1   85  66     29    0  26.6   0.351  31   0
# 2   8  183  64      0    0  23.3   0.672  32   1
# 3   1   89  66     23   94  28.1   0.167  21   0
# 4   0  137  40     35  168  43.1   2.288  33   1
# 5   5  116  74      0    0  25.6   0.201  30   0

# %%
df.iloc[[0, 5]]
# Out:
#    임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 0   6  148  72     35    0  33.6   0.627  50   1
# 5   5  116  74      0    0  25.6   0.201  30   0

# %%
df.set_index("결과")
# Out:
#     임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이
# 결과
# 1    6  148  72     35    0  33.6   0.627  50
# 0    1   85  66     29    0  26.6   0.351  31
# 1    8  183  64      0    0  23.3   0.672  32
# 0    1   89  66     23   94  28.1   0.167  21
# 1    0  137  40     35  168  43.1   2.288  33
# ..  ..  ...  ..    ...  ...   ...     ...  ..
# 0   10  101  76     48  180  32.9   0.171  63
# 0    2  122  70     27    0  36.8   0.340  27
# 0    5  121  72     23  112  26.2   0.245  30
# 1    1  126  60      0    0  30.1   0.349  47
# 0    1   93  70     31    0  30.4   0.315  23
#
# [768 rows x 8 columns]

# %%
df.loc[[0], ["임신", "혈압", "인슐린", "나이", "결과"]]
# Out:
#    임신  혈압  인슐린  나이  결과
# 0   6  72    0  50   1

# %%
df.loc[[0, 5, 415, 600], ["나이"]]
# Out:
#      나이
# 0    50
# 5    30
# 415  22
# 600  24

# %%
df.loc[0] = [6, 148, 72, 35, 0, 33.6, 0.627, 55, 1]
df.head(3)
# Out:
#    임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 0   6  148  72     35    0  33.6   0.627  55   1
# 1   1   85  66     29    0  26.6   0.351  31   0
# 2   8  183  64      0    0  23.3   0.672  32   1

# %%
sort_df = df.sort_values('나이', ascending=False) # 내림차순
sort_df
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 459   9  134  74     33   60  25.9   0.460  81   0
# 453   2  119   0      0    0  19.6   0.832  72   0
# 666   4  145  82     18    0  32.5   0.235  70   1
# 684   5  136  82      0    0   0.0   0.640  69   0
# 123   5  132  80      0    0  26.8   0.186  69   0
# ..   ..  ...  ..    ...  ...   ...     ...  ..  ..
# 240   1   91  64     24    0  29.2   0.192  21   0
# 136   0  100  70     26   50  30.8   0.597  21   0
# 382   1  109  60      8  182  25.4   0.947  21   0
# 392   1  131  64     14  415  23.7   0.389  21   0
# 271   2  108  62     32   56  25.2   0.128  21   0
#
# [768 rows x 9 columns]

# %%
sort_df.drop(['임신', '포도당'], axis=1)
# Out:
#      혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 459  74     33   60  25.9   0.460  81   0
# 453   0      0    0  19.6   0.832  72   0
# 666  82     18    0  32.5   0.235  70   1
# 684  82      0    0   0.0   0.640  69   0
# 123  80      0    0  26.8   0.186  69   0
# ..   ..    ...  ...   ...     ...  ..  ..
# 240  64     24    0  29.2   0.192  21   0
# 136  70     26   50  30.8   0.597  21   0
# 382  60      8  182  25.4   0.947  21   0
# 392  64     14  415  23.7   0.389  21   0
# 271  62     32   56  25.2   0.128  21   0
#
# [768 rows x 7 columns]

# %%
df.to_json('/content/drive/My Drive/lion/PART17/dataset/indian_diabetes.json')

# %%
json_df = pd.read_json('/content/drive/My Drive/lion/PART17/dataset/indian_diabetes.json')
json_df
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병  나이  결과
# 0     6  148  72     35    0  33.6   0.627  55   1
# 1     1   85  66     29    0  26.6   0.351  31   0
# 2     8  183  64      0    0  23.3   0.672  32   1
# 3     1   89  66     23   94  28.1   0.167  21   0
# 4     0  137  40     35  168  43.1   2.288  33   1
# ..   ..  ...  ..    ...  ...   ...     ...  ..  ..
# 763  10  101  76     48  180  32.9   0.171  63   0
# 764   2  122  70     27    0  36.8   0.340  27   0
# 765   5  121  72     23  112  26.2   0.245  30   0
# 766   1  126  60      0    0  30.1   0.349  47   1
# 767   1   93  70     31    0  30.4   0.315  23   0
#
# [768 rows x 9 columns]

# %%
# 판다스 통계
print( json_df.mean() )
print( "-----------------------------------------" )
print( json_df.median() )
print( "-----------------------------------------" )
print( json_df.max() )
print( "-----------------------------------------" )
print( json_df.min() )
print( "-----------------------------------------" )
print( json_df.std() )
print( "-----------------------------------------" )
print( json_df.corr() )
print( "-----------------------------------------" )
print( json_df.info() )
print( "-----------------------------------------" )
print( json_df.describe() )
print( "-----------------------------------------" )
# Out:
# 임신          3.845052
# 포도당       120.894531
# 혈압         69.105469
# 피부 두께      20.536458
# 인슐린        79.799479
# BMI        31.992578
# 당뇨계열 병      0.471876
# 나이         33.247396
# 결과          0.348958
# dtype: float64
# -----------------------------------------
# 임신          3.0000
# 포도당       117.0000
# 혈압         72.0000
# 피부 두께      23.0000
# 인슐린        30.5000
# BMI        32.0000
# 당뇨계열 병      0.3725
# 나이         29.0000
# 결과          0.0000
# dtype: float64
# -----------------------------------------
# 임신         17.00
# 포도당       199.00
# 혈압        122.00
# 피부 두께      99.00
# 인슐린       846.00
# BMI        67.10
# 당뇨계열 병      2.42
# 나이         81.00
# 결과          1.00
# dtype: float64
# -----------------------------------------
# 임신         0.000
# 포도당        0.000
# 혈압         0.000
# 피부 두께      0.000
# 인슐린        0.000
# BMI        0.000
# 당뇨계열 병     0.078
# 나이        21.000
# 결과         0.000
# dtype: float64
# -----------------------------------------
# 임신          3.369578
# 포도당        31.972618
# 혈압         19.355807
# 피부 두께      15.952218
# 인슐린       115.244002
# BMI         7.884160
# 당뇨계열 병      0.331329
# 나이         11.770901
# 결과          0.476951
# dtype: float64
# -----------------------------------------
#               임신       포도당        혈압  ...    당뇨계열 병        나이        결과
# 임신      1.000000  0.129459  0.141282  ... -0.033523  0.544202  0.221898
# 포도당     0.129459  1.000000  0.152590  ...  0.137337  0.263745  0.466581
# 혈압      0.141282  0.152590  1.000000  ...  0.041265  0.239394  0.065068
# 피부 두께  -0.081672  0.057328  0.207371  ...  0.183928 -0.113365  0.074752
# 인슐린    -0.073535  0.331357  0.088933  ...  0.185071 -0.042508  0.130548
# BMI     0.017683  0.221071  0.281805  ...  0.140647  0.036322  0.292695
# 당뇨계열 병 -0.033523  0.137337  0.041265  ...  1.000000  0.033790  0.173844
# 나이      0.544202  0.263745  0.239394  ...  0.033790  1.000000  0.238896
# 결과      0.221898  0.466581  0.065068  ...  0.173844  0.238896  1.000000
#
# [9 rows x 9 columns]
# -----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   임신      768 non-null    int64
#  1   포도당     768 non-null    int64
#  2   혈압      768 non-null    int64
#  3   피부 두께   768 non-null    int64
#  4   인슐린     768 non-null    int64
#  5   BMI     768 non-null    float64
#  6   당뇨계열 병  768 non-null    float64
#  7   나이      768 non-null    int64
#  8   결과      768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 60.0 KB
# None
# -----------------------------------------
#                임신         포도당          혈압  ...      당뇨계열 병          나이          결과
# count  768.000000  768.000000  768.000000  ...  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469  ...    0.471876   33.247396    0.348958
# std      3.369578   31.972618   19.355807  ...    0.331329   11.770901    0.476951
# min      0.000000    0.000000    0.000000  ...    0.078000   21.000000    0.000000
# 25%      1.000000   99.000000   62.000000  ...    0.243750   24.000000    0.000000
# 50%      3.000000  117.000000   72.000000  ...    0.372500   29.000000    0.000000
# 75%      6.000000  140.250000   80.000000  ...    0.626250   41.000000    1.000000
# max     17.000000  199.000000  122.000000  ...    2.420000   81.000000    1.000000
#
# [8 rows x 9 columns]
# -----------------------------------------

# %%
json_df['BMI'].value_counts(dropna=False)
json_df.loc[0] = [6, 148, 72, 35, 0, 33.6, 0.627, None, 1]

# %%
json_df.isnull().sum()
# Out:
# 임신        0
# 포도당       0
# 혈압        0
# 피부 두께     0
# 인슐린       0
# BMI       0
# 당뇨계열 병    0
# 나이        1
# 결과        0
# dtype: int64

# %%
# 열 중에서, 100개 넘으면 열 제거하기
json_df.dropna(axis=1, thresh=100)
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병    나이  결과
# 0     6  148  72     35    0  33.6   0.627   NaN   1
# 1     1   85  66     29    0  26.6   0.351  31.0   0
# 2     8  183  64      0    0  23.3   0.672  32.0   1
# 3     1   89  66     23   94  28.1   0.167  21.0   0
# 4     0  137  40     35  168  43.1   2.288  33.0   1
# ..   ..  ...  ..    ...  ...   ...     ...   ...  ..
# 763  10  101  76     48  180  32.9   0.171  63.0   0
# 764   2  122  70     27    0  36.8   0.340  27.0   0
# 765   5  121  72     23  112  26.2   0.245  30.0   0
# 766   1  126  60      0    0  30.1   0.349  47.0   1
# 767   1   93  70     31    0  30.4   0.315  23.0   0
#
# [768 rows x 9 columns]

# %%
# 나이에서 NaN 이 있는 경우 데이터 제거
json_df.dropna(subset=['나이'], how='any', axis=0)
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병    나이  결과
# 1     1   85  66     29    0  26.6   0.351  31.0   0
# 2     8  183  64      0    0  23.3   0.672  32.0   1
# 3     1   89  66     23   94  28.1   0.167  21.0   0
# 4     0  137  40     35  168  43.1   2.288  33.0   1
# 5     5  116  74      0    0  25.6   0.201  30.0   0
# ..   ..  ...  ..    ...  ...   ...     ...   ...  ..
# 763  10  101  76     48  180  32.9   0.171  63.0   0
# 764   2  122  70     27    0  36.8   0.340  27.0   0
# 765   5  121  72     23  112  26.2   0.245  30.0   0
# 766   1  126  60      0    0  30.1   0.349  47.0   1
# 767   1   93  70     31    0  30.4   0.315  23.0   0
#
# [767 rows x 9 columns]

# %%
# 나이에서 NaN 이 있는 경우 데이터 제거
json_df.loc[0] = [6, 148, 72, 35, 0, 33.6, 0.627, None, 1]
json_df['나이'].fillna( json_df['나이'].median(axis=0), inplace=True )
json_df
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병    나이  결과
# 0     6  148  72     35    0  33.6   0.627  29.0   1
# 1     1   85  66     29    0  26.6   0.351  31.0   0
# 2     8  183  64      0    0  23.3   0.672  32.0   1
# 3     1   89  66     23   94  28.1   0.167  21.0   0
# 4     0  137  40     35  168  43.1   2.288  33.0   1
# ..   ..  ...  ..    ...  ...   ...     ...   ...  ..
# 763  10  101  76     48  180  32.9   0.171  63.0   0
# 764   2  122  70     27    0  36.8   0.340  27.0   0
# 765   5  121  72     23  112  26.2   0.245  30.0   0
# 766   1  126  60      0    0  30.1   0.349  47.0   1
# 767   1   93  70     31    0  30.4   0.315  23.0   0
#
# [768 rows x 9 columns]

# %%
json_df.loc[1] = [6, 148, 72, 35, 0, 33.6, 0.627, 29.0, 1]
json_df.drop_duplicates()
# Out:
#      임신  포도당  혈압  피부 두께  인슐린   BMI  당뇨계열 병    나이  결과
# 0     6  148  72     35    0  33.6   0.627  29.0   1
# 2     8  183  64      0    0  23.3   0.672  32.0   1
# 3     1   89  66     23   94  28.1   0.167  21.0   0
# 4     0  137  40     35  168  43.1   2.288  33.0   1
# 5     5  116  74      0    0  25.6   0.201  30.0   0
# ..   ..  ...  ..    ...  ...   ...     ...   ...  ..
# 763  10  101  76     48  180  32.9   0.171  63.0   0
# 764   2  122  70     27    0  36.8   0.340  27.0   0
# 765   5  121  72     23  112  26.2   0.245  30.0   0
# 766   1  126  60      0    0  30.1   0.349  47.0   1
# 767   1   93  70     31    0  30.4   0.315  23.0   0
#
# [767 rows x 9 columns]

# %%
# 런타임 초기화 -> 다시 시작 및 모두 실행
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import warnings
warnings.filterwarnings(action='ignore')

import missingno as msno
msno.matrix(json_df, figsize=(12,5))

# %%
# 날짜 데이터
commerce_df = pd.read_csv('/content/drive/My Drive/lion/PART17/dataset/commerce.csv', encoding='unicode_escape')
commerce_df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %%
commerce_df['parse_InvoiceDate'] = pd.to_datetime(commerce_df['InvoiceDate'])
commerce_df
# Out:
#        InvoiceNo StockCode  ...         Country   parse_InvoiceDate
# 0         536365    85123A  ...  United Kingdom 2010-12-01 08:26:00
# 1         536365     71053  ...  United Kingdom 2010-12-01 08:26:00
# 2         536365    84406B  ...  United Kingdom 2010-12-01 08:26:00
# 3         536365    84029G  ...  United Kingdom 2010-12-01 08:26:00
# 4         536365    84029E  ...  United Kingdom 2010-12-01 08:26:00
# ...          ...       ...  ...             ...                 ...
# 541904    581587     22613  ...          France 2011-12-09 12:50:00
# 541905    581587     22899  ...          France 2011-12-09 12:50:00
# 541906    581587     23254  ...          France 2011-12-09 12:50:00
# 541907    581587     23255  ...          France 2011-12-09 12:50:00
# 541908    581587     22138  ...          France 2011-12-09 12:50:00
#
# [541909 rows x 9 columns]

# %%
commerce_df['year_InvoiceDate'] = commerce_df['parse_InvoiceDate'].dt.year
commerce_df['month_InvoiceDate'] = commerce_df['parse_InvoiceDate'].dt.month
commerce_df['day_InvoiceDate'] = commerce_df['parse_InvoiceDate'].dt.day

print( commerce_df['parse_InvoiceDate'].dt.year )
print( commerce_df['parse_InvoiceDate'].dt.month )
print( commerce_df['parse_InvoiceDate'].dt.day )

commerce_df
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: parse_InvoiceDate, Length: 541909, dtype: int64
# 0         12
# 1         12
# 2         12
# 3         12
# 4         12
#           ..
# 541904    12
# 541905    12
# 541906    12
# 541907    12
# 541908    12
# Name: parse_InvoiceDate, Length: 541909, dtype: int64
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 541904    9
# 541905    9
# 541906    9
# 541907    9
# 541908    9
# Name: parse_InvoiceDate, Length: 541909, dtype: int64
#        InvoiceNo StockCode  ... month_InvoiceDate  day_InvoiceDate
# 0         536365    85123A  ...                12                1
# 1         536365     71053  ...                12                1
# 2         536365    84406B  ...                12                1
# 3         536365    84029G  ...                12                1
# 4         536365    84029E  ...                12                1
# ...          ...       ...  ...               ...              ...
# 541904    581587     22613  ...                12                9
# 541905    581587     22899  ...                12                9
# 541906    581587     23254  ...                12                9
# 541907    581587     23255  ...                12                9
# 541908    581587     22138  ...                12                9
#
# [541909 rows x 12 columns]

# %%
commerce_df[ (commerce_df['year_InvoiceDate'] == 2011) & (commerce_df['CustomerID'] == 13313.0) ]
# Out:
#        InvoiceNo StockCode  ... month_InvoiceDate  day_InvoiceDate
# 42481     539993     22386  ...                 1                4
# 42482     539993     21499  ...                 1                4
# 42483     539993     21498  ...                 1                4
# 42484     539993     22379  ...                 1                4
# 42485     539993     20718  ...                 1                4
# ...          ...       ...  ...               ...              ...
# 478667    577099     23203  ...                11               17
# 478668    577099     22303  ...                11               17
# 478669    577099     22302  ...                11               17
# 478670    577099     84755  ...                11               17
# 478671    577099     23350  ...                11               17
#
# [78 rows x 12 columns]
